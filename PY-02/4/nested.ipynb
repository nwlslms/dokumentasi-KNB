# %%
a = int(input("Jumlah baris: "))
for i in range(a):
    for j in range(i + 1):
        print('*', end='')
    print()
print()
for i in range(a):
    #spasi
    for j in range(i):
        print(end=" ")

    #bintang
    for j in range(i, a):
        print('*', end='')
    print()
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********
# *********
# **********
#
# **********
#  *********
#   ********
#    *******
#     ******
#      *****
#       ****
#        ***
#         **
#          *
